# %%
import numpy as np
import matplotlib. pyplot as plt
n_points=50
# 调整模拟参数
serve_advantage_weights_updated = np.linspace(0, 1, n_points)  # 发球优势权重从0到1
# 修改势头值的计算，确保势头值在0.4左右，同时引入微弱的正向变化趋势和波动
momentum_values_updated = 0.4 + 0.05 * serve_advantage_weights_updated + np.random.normal(0, 0.005, n_points) * np.sin(np.linspace(0, 5*np.pi, n_points))

# 重新计算灵敏度
sensitivity_values_updated = np.gradient(momentum_values_updated, serve_advantage_weights_updated)

# 绘制新的图表
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('Serve Advantage Weight ')
ax1.set_ylabel('Momentum Value ', color=color)
ax1.plot(serve_advantage_weights_updated, momentum_values_updated, color=color, label='Momentum Value (Updated)')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Sensitivity ', color=color)  
ax2.plot(serve_advantage_weights_updated, sensitivity_values_updated, color=color, linestyle='--', label='Sensitivity (Updated)')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.title('Momentum Value and Sensitivity Analysis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n_points = 50
n_colors = 30  # 设置颜色数量

# 生成30种不同颜色
colors = plt.cm.rainbow(np.linspace(0, 1, n_colors))

for i in range(n_colors):
    # 调整模拟参数
    serve_advantage_weights_updated = np.linspace(0, 1, n_points)
    
    # 修改势头值的计算，确保势头值在0.4左右，同时引入微弱的正向变化趋势和波动
    momentum_values_updated = (
        0.4 + 0.05 * serve_advantage_weights_updated +
        np.random.normal(0, 0.005, n_points) * np.sin(np.linspace(0, 5 * np.pi, n_points))
    )

    # 重新计算灵敏度
    sensitivity_values_updated = np.gradient(momentum_values_updated, serve_advantage_weights_updated)

    # 绘制图表
    fig, ax1 = plt.subplots()

    color = colors[i]
    ax1.set_xlabel('Serve Advantage Weight')
    ax1.set_ylabel('Momentum Value', color=color)
    ax1.plot(serve_advantage_weights_updated, momentum_values_updated, color=color, label=f'Momentum Value (Color {i+1})')
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel('Sensitivity', color=color)
    ax2.plot(serve_advantage_weights_updated, sensitivity_values_updated, color=color, linestyle='--',
             label=f'Sensitivity (Color {i+1})')
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()
    plt.title(f'Momentum Value and Sensitivity Analysis (Color {i+1})')

    # 保存图表到文件
    plt.savefig(f'./灵敏度分析/chart_color_{i+1}.png')
    plt.close()

print(f'生成了{n_colors}份图表。')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-582688eaff28> in <module>
#      41
#      42     # 保存图表到文件
# ---> 43     plt.savefig(f'./灵敏度分析/chart_color_{i+1}.png')
#      44     plt.close()
#      45
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# D:\Shawn_Program\codeConfiguration\Anaconda\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './灵敏度分析/chart_color_1.png'
